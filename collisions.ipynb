# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.DataFrame.from_csv('cycling_collisions_toronto_1986-2010.xls.csv', index_col='ID')
titles.head()
# Out:
#      INJURY    INJURYCODE                     INJURY2 SAFETY EQUIP.  \
# ID
# 1   Minimal    small_blue  sustained minimal injuries    Unrecorded
# 2   Minimal    small_blue  sustained minimal injuries    Unrecorded
# 3     Minor  small_purple    sustained minor injuries    Unrecorded
# 4   Minimal    small_blue  sustained minimal injuries    Unrecorded
# 5   Minimal    small_blue  sustained minimal injuries    Unrecorded
#
#    SAFETY EQUIP.2      ROAD CLASS     ROAD CLASS2 CYCLIST CRASH TYPE  \
# ID
# 1      unrecorded  Minor Arterial  minor arterial         Unrecorded
# 2      unrecorded  Major Arterial  major arterial         Unrecorded
# 3      unrecorded  Major Arterial  major arterial         Unrecorded
# 4      unrecorded           Local           local         Unrecorded
# 5      unrecorded  Major Arterial  major arterial         Unrecorded
#
#                                CYCLIST CRASH TYPE2 AGE OF CYCLIST  ...   \
# ...

# %%
df = titles[['INJURY','SAFETY EQUIP.','ROAD CLASS','CYCLIST CRASH TYPE','AGE OF CYCLIST','STNAME1','STREET 1 TYPE','STNAME 2','STREET 2 TYPE','LONG','LAT','ACC TIME','ACC TIME2','TRAFFIC CONTROL','ROAD SURFACE2','DATE','DATE2','DRIVER ACTION','DRIVER CONDITION','YEAR']]

# %%
df.head()
# Out:
#      INJURY SAFETY EQUIP.      ROAD CLASS CYCLIST CRASH TYPE AGE OF CYCLIST  \
# ID
# 1   Minimal    Unrecorded  Minor Arterial         Unrecorded             34
# 2   Minimal    Unrecorded  Major Arterial         Unrecorded             54
# 3     Minor    Unrecorded  Major Arterial         Unrecorded             19
# 4   Minimal    Unrecorded           Local         Unrecorded             34
# 5   Minimal    Unrecorded  Major Arterial         Unrecorded             34
#
#        STNAME1 STREET 1 TYPE      STNAME 2 STREET 2 TYPE       LONG       LAT  \
# ID
# 1   BIRCHMOUNT          ROAD      HIGHVIEW            AV  -79.26539  43.69987
# 2    LAKESHORE            BV  THIRTY-FIFTH            ST    -79.535   43.5941
# 3     LAWRENCE            AV       FORTUNE          GATE    -79.218   43.7614
# 4       EUCLID            AV        ULSTER            ST   -79.4133   43.6599
# 5     DANFORTH            AV       DRAYTON            AV  -79.32041  43.68403
#
# ...

# %%
df.to_csv('collisions.csv')

# %%
col_df = pd.DataFrame.from_csv('collisions.csv', index_col='ID')

# %%
col_df=col_df.sort_index()

# %%
col_df
# Out:
#         INJURY                     SAFETY EQUIP.      ROAD CLASS  \
# ID
# 1      Minimal                        Unrecorded  Minor Arterial
# 2      Minimal                        Unrecorded  Major Arterial
# 3        Minor                        Unrecorded  Major Arterial
# 4      Minimal                        Unrecorded           Local
# 5      Minimal                        Unrecorded  Major Arterial
# 6      Minimal                        Unrecorded  Minor Arterial
# 7      Minimal                        Unrecorded  Major Arterial
# 8        Minor                        Unrecorded  Major Arterial
# 9      Minimal                        Unrecorded  Major Arterial
# 10       Minor                        Unrecorded  Minor Arterial
# 11       Minor                        Unrecorded  Major Arterial
# 12     Minimal                        Unrecorded  Major Arterial
# 13       Major                        Unrecorded  Major Arterial
# ...

# %%
import geocoder

# %%
g = geocoder.arcgis([45.16,-75.14], method='reverse')

# %%
g.address
# Out:
# 'Berwick Rd & Goldfield Rd N, North Stormont, Ontario, K0C'

# %%
coords = col_df[['LAT','LONG']]
geo = [[]]

# %%
for index, row in coords.iterrows():
    geo[index] = [row['LAT'],row['LONG']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-d2cb7c70587c> in <module>()
#       1 for index, row in coords.iterrows():
# ----> 2     geo[index] = [row['LAT'],row['LONG']]
#
# IndexError: list assignment index out of range
